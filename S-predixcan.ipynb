# %%
import numpy
import scipy
import pandas
import sqlalchemy
import patsy
import statsmodels
import h5py

# !git clone https://github.com/hakyimlab/MetaXcan
# !cd MetaXcan/software
# Out:
# fatal: destination path 'MetaXcan' already exists and is not an empty directory.

# %%
#harmonize data set for s-predixcan
# !python MetaXcan/software/M03_betas.py \
--snp_map_file /Users/halk/Downloads/data/coordinate_map/map_snp150_hg38.txt.gz \
--gwas_file /Users/halk/liftoveredgwas.txt \
--snp_column rsID \
--non_effect_allele_column NEA \
--effect_allele_column EA \
--beta_column BETA \
--pvalue_column P \
--keep_non_rsid \
--throw \
--output output/newharmonizedgwas.txt.gz
# Out:
# INFO - Processing GWAS command line parameters
# INFO - Building beta for /Users/halk/liftoveredgwas.txt and no database
# INFO - Reading input gwas: /Users/halk/liftoveredgwas.txt
# INFO - Processing input gwas
# INFO - Loading mapping
# INFO - Mapping variants
# INFO - Saving output/newharmonizedgwas.txt.gz
# INFO - Successfully ran GWAS input processing in 364.9786541650001 seconds

# %%
#TWAS on whole blood
# !python MetaXcan/software/SPrediXcan.py \
--gwas_file /Users/halk/output/newharmonizedgwas.txt.gz \
--snp_column snp \
--effect_allele_column effect_allele \
--non_effect_allele_column non_effect_allele \
--zscore_column zscore \
--model_db_path /Users/halk/Downloads/eqtl/mashr/mashr_Whole_Blood.db \
--covariance /Users/halk/Downloads/eqtl/mashr/mashr_Whole_Blood.txt.gz \
--keep_non_rsid \
--additional_output \
--model_db_snp_key varID \
--throw \
--output_file output/Wholebloodresults.csv
# Out:
# INFO - Processing GWAS command line parameters
# INFO - Building beta for /Users/halk/output/newharmonizedgwas.txt.gz and /Users/halk/Downloads/eqtl/mashr/mashr_Whole_Blood.db
# INFO - Reading input gwas with special handling: /Users/halk/output/newharmonizedgwas.txt.gz
# INFO - Processing input gwas
# INFO - Aligning GWAS to models
# INFO - Trimming output
# INFO - Successfully parsed input gwas in 11.648683043999881 seconds
# INFO - Started metaxcan process
# INFO - Loading model from: /Users/halk/Downloads/eqtl/mashr/mashr_Whole_Blood.db
# INFO - Loading covariance data from: /Users/halk/Downloads/eqtl/mashr/mashr_Whole_Blood.txt.gz
# INFO - Processing loaded gwas
# INFO - Started metaxcan association
# INFO - 10 % of model's snps found so far in the gwas study
# INFO - 20 % of model's snps found so far in the gwas study
# INFO - 30 % of model's snps found so far in the gwas study
# INFO - 40 % of model's snps found so far in the gwas study
# INFO - 50 % of model's snps found so far in the gwas study
# INFO - 60 % of model's snps found so far in the gwas study
# INFO - 70 % of model's snps found so far in the gwas study
# INFO - 75 % of model's snps used
# INFO - Sucessfully processed metaxcan association in 9.038065677999839 seconds

# %%
#TWAS on skin no sun
# !python MetaXcan/software/SPrediXcan.py \
--gwas_file /Users/halk/output/newharmonizedgwas.txt.gz \
--snp_column snp \
--effect_allele_column effect_allele \
--non_effect_allele_column non_effect_allele \
--zscore_column zscore \
--model_db_path /Users/halk/Downloads/eqtl/mashr/mashr_Skin_Not_Sun_Exposed_Suprapubic.db \
--covariance /Users/halk/Downloads/eqtl/mashr/mashr_Skin_Not_Sun_Exposed_Suprapubic.txt.gz \
--keep_non_rsid \
--additional_output \
--model_db_snp_key varID \
--throw \
--output_file output/Skinnosunresults.csv
# Out:
# INFO - Processing GWAS command line parameters
# INFO - Building beta for /Users/halk/output/newharmonizedgwas.txt.gz and /Users/halk/Downloads/eqtl/mashr/mashr_Skin_Not_Sun_Exposed_Suprapubic.db
# INFO - Reading input gwas with special handling: /Users/halk/output/newharmonizedgwas.txt.gz
# INFO - Processing input gwas
# INFO - Aligning GWAS to models
# INFO - Trimming output
# INFO - Successfully parsed input gwas in 16.432008775000213 seconds
# INFO - Started metaxcan process
# INFO - Loading model from: /Users/halk/Downloads/eqtl/mashr/mashr_Skin_Not_Sun_Exposed_Suprapubic.db
# INFO - Loading covariance data from: /Users/halk/Downloads/eqtl/mashr/mashr_Skin_Not_Sun_Exposed_Suprapubic.txt.gz
# INFO - Processing loaded gwas
# INFO - Started metaxcan association
# INFO - 10 % of model's snps found so far in the gwas study
# INFO - 20 % of model's snps found so far in the gwas study
# INFO - 30 % of model's snps found so far in the gwas study
# INFO - 40 % of model's snps found so far in the gwas study
# INFO - 50 % of model's snps found so far in the gwas study
# INFO - 60 % of model's snps found so far in the gwas study
# INFO - 70 % of model's snps found so far in the gwas study
# INFO - 76 % of model's snps used
# INFO - Sucessfully processed metaxcan association in 18.075587567000184 seconds

# %%
#TWAS on Skin Sun exposed
# !python MetaXcan/software/SPrediXcan.py \
--gwas_file /Users/halk/output/newharmonizedgwas.txt.gz \
--snp_column snp \
--effect_allele_column effect_allele \
--non_effect_allele_column non_effect_allele \
--zscore_column zscore \
--model_db_path /Users/halk/Downloads/eqtl/mashr/mashr_Skin_Sun_Exposed_Lower_leg.db \
--covariance /Users/halk/Downloads/eqtl/mashr/mashr_Skin_Sun_Exposed_Lower_leg.txt.gz \
--keep_non_rsid \
--additional_output \
--model_db_snp_key varID \
--throw \
--output_file output/skinsunexposed.csv
# Out:
# INFO - Processing GWAS command line parameters
# INFO - Building beta for /Users/halk/output/newharmonizedgwas.txt.gz and /Users/halk/Downloads/eqtl/mashr/mashr_Skin_Sun_Exposed_Lower_leg.db
# INFO - Reading input gwas with special handling: /Users/halk/output/newharmonizedgwas.txt.gz
# INFO - Processing input gwas
# INFO - Aligning GWAS to models
# INFO - Trimming output
# INFO - Successfully parsed input gwas in 16.14362960700055 seconds
# INFO - Started metaxcan process
# INFO - Loading model from: /Users/halk/Downloads/eqtl/mashr/mashr_Skin_Sun_Exposed_Lower_leg.db
# INFO - Loading covariance data from: /Users/halk/Downloads/eqtl/mashr/mashr_Skin_Sun_Exposed_Lower_leg.txt.gz
# INFO - Processing loaded gwas
# INFO - Started metaxcan association
# INFO - 10 % of model's snps found so far in the gwas study
# INFO - 20 % of model's snps found so far in the gwas study
# INFO - 30 % of model's snps found so far in the gwas study
# INFO - 40 % of model's snps found so far in the gwas study
# INFO - 50 % of model's snps found so far in the gwas study
# INFO - 60 % of model's snps found so far in the gwas study
# INFO - 70 % of model's snps found so far in the gwas study
# INFO - 75 % of model's snps used
# INFO - Sucessfully processed metaxcan association in 18.799005187000148 seconds

# %%
#TWAS on Fibroblasts
# !python MetaXcan/software/SPrediXcan.py \
--gwas_file /Users/halk/output/newharmonizedgwas.txt.gz \
--snp_column snp \
--effect_allele_column effect_allele \
--non_effect_allele_column non_effect_allele \
--zscore_column zscore \
--model_db_path /Users/halk/Downloads/data/models/eqtl/mashr/mashr_Cells_Cultured_fibroblasts.db\
--covariance /Users/halk/Downloads/eqtl/mashr/mashr_Cells_Cultured_fibroblasts.txt.gz\
--keep_non_rsid \
--additional_output \
--model_db_snp_key varID \
--throw \
--output_file output/fibroblastresults.csv
# Out:
# INFO - Processing GWAS command line parameters
# INFO - Building beta for /Users/halk/output/newharmonizedgwas.txt.gz and /Users/halk/Downloads/data/models/eqtl/mashr/mashr_Cells_Cultured_fibroblasts.db
# INFO - Reading input gwas with special handling: /Users/halk/output/newharmonizedgwas.txt.gz
# INFO - Processing input gwas
# INFO - Aligning GWAS to models
# INFO - Trimming output
# INFO - Successfully parsed input gwas in 25.057319163000102 seconds
# INFO - Started metaxcan process
# INFO - Loading model from: /Users/halk/Downloads/data/models/eqtl/mashr/mashr_Cells_Cultured_fibroblasts.db
# INFO - Loading covariance data from: /Users/halk/Downloads/eqtl/mashr/mashr_Cells_Cultured_fibroblasts.txt.gz
# INFO - Processing loaded gwas
# INFO - Started metaxcan association
# INFO - 10 % of model's snps found so far in the gwas study
# INFO - 20 % of model's snps found so far in the gwas study
# INFO - 30 % of model's snps found so far in the gwas study
# INFO - 40 % of model's snps found so far in the gwas study
# INFO - 50 % of model's snps found so far in the gwas study
# INFO - 60 % of model's snps found so far in the gwas study
# INFO - 70 % of model's snps found so far in the gwas study
# INFO - 76 % of model's snps used
# INFO - Sucessfully processed metaxcan association in 29.43338908700025 seconds

# %%
#TWAS on Lymphocytes
# !python MetaXcan/software/SPrediXcan.py \
--gwas_file /Users/halk/output/newharmonizedgwas.txt.gz \
--snp_column snp \
--effect_allele_column effect_allele \
--non_effect_allele_column non_effect_allele \
--zscore_column zscore \
--model_db_path /Users/halk/Downloads/data/models/sqtl/mashr/mashr_Cells_EBV-transformed_lymphocytes.db \
--covariance /Users/halk/Downloads/eqtl/mashr/mashr_Cells_EBV-transformed_lymphocytes.txt.gz \
--keep_non_rsid \
--additional_output \
--model_db_snp_key varID \
--throw \
--output_file output/ebvlymphocytesresults.csv
# Out:
# INFO - Processing GWAS command line parameters
# INFO - Building beta for /Users/halk/output/newharmonizedgwas.txt.gz and /Users/halk/Downloads/data/models/sqtl/mashr/mashr_Cells_EBV-transformed_lymphocytes.db
# INFO - Reading input gwas with special handling: /Users/halk/output/newharmonizedgwas.txt.gz
# INFO - Processing input gwas
# INFO - Aligning GWAS to models
# INFO - Trimming output
# INFO - Successfully parsed input gwas in 14.017939190000106 seconds
# INFO - Started metaxcan process
# INFO - Loading model from: /Users/halk/Downloads/data/models/sqtl/mashr/mashr_Cells_EBV-transformed_lymphocytes.db
# INFO - Loading covariance data from: /Users/halk/Downloads/eqtl/mashr/mashr_Cells_EBV-transformed_lymphocytes.txt.gz
# INFO - Processing loaded gwas
# INFO - Started metaxcan association
# INFO - 0 % of model's snps used
# INFO - Sucessfully processed metaxcan association in 59.37470667699927 seconds

# %%
# !pip install qmplot
# Out:
# Collecting qmplot
#   Downloading qmplot-0.3.3.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in ./anaconda3/lib/python3.10/site-packages (from qmplot) (1.26.4)
# Requirement already satisfied: scipy in ./anaconda3/lib/python3.10/site-packages (from qmplot) (1.13.1)
# Requirement already satisfied: pandas in ./anaconda3/lib/python3.10/site-packages (from qmplot) (2.2.2)
# Requirement already satisfied: matplotlib in ./anaconda3/lib/python3.10/site-packages (from qmplot) (3.7.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./anaconda3/lib/python3.10/site-packages (from matplotlib->qmplot) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in ./anaconda3/lib/python3.10/site-packages (from matplotlib->qmplot) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./anaconda3/lib/python3.10/site-packages (from matplotlib->qmplot) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in ./anaconda3/lib/python3.10/site-packages (from matplotlib->qmplot) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./anaconda3/lib/python3.10/site-packages (from matplotlib->qmplot) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in ./anaconda3/lib/python3.10/site-packages (from matplotlib->qmplot) (22.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./anaconda3/lib/python3.10/site-packages (from matplotlib->qmplot) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./anaconda3/lib/python3.10/site-packages (from matplotlib->qmplot) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/lib/python3.10/site-packages (from pandas->qmplot) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in ./anaconda3/lib/python3.10/site-packages (from pandas->qmplot) (2024.1)
# Requirement already satisfied: six>=1.5 in ./anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->qmplot) (1.16.0)
# Building wheels for collected packages: qmplot
#   Building wheel for qmplot (setup.py) ... done
#   Created wheel for qmplot: filename=qmplot-0.3.3-py3-none-any.whl size=25598 sha256=d3dcac7f110c947d8b8c5ef1aff1d97992fb952e69a4062474dcd4d995b449a2
#   Stored in directory: /Users/halk/Library/Caches/pip/wheels/e5/a1/ea/c196f3c504ab9aa93f0f568a1ed6cd3a6591b7258527e3ffb9
# Successfully built qmplot
# Installing collected packages: qmplot
# Successfully installed qmplot-0.3.3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
#Upload whole blood results
WB= pd.read_csv('/Users/halk/output/Wholebloodresults.csv')

# %%
#create bar plot for lead genes from WB twas
def lead_genes_plot(WB, lead_n=10, gene_col='gene_name', p_value_col= 'pvalue'):
    lead_genes= WB.nsmallest(lead_n, p_value_col)
    lead_genes['-log10(pvalue)']= -np.log10(lead_genes[p_value_col])
    
    plt.figure(figsize=(12,10))
    sns.barplot(x='-log10(pvalue)', y=gene_col, data= lead_genes)
    plt.xlabel('-log10(p-value)')
    plt.ylabel('Gene')
    plt.title('Top 10 Significant Genes for Whole Blood')
    plt.savefig('WBtop10.png')
    plt.show()
    
lead_genes_plot(WB)

# %%
#Create QQ plot for all 4 tissue
from scipy import stats
def qq_plot(dfs, pvalue_cols,labels):
    plt.figure(figsize=(10,10))
    
    max_expected=0
    max_observed =0
    
    
    for i, df in enumerate(dfs):
    
        pvalues= df[pvalue_cols[i]]
   
    #Calculate expected qs
        sorted_pvalues = np.sort(pvalues)
        expected_qs = -np.log10(np.linspace(1/ len(sorted_pvalues),1, len(sorted_pvalues)))
    
    #calculate observed -log10ps
        observed_qs= -np.log10(sorted_pvalues)
    
       #create values for reference line
        max_expected= max(max_expected, max(expected_qs))
        max_observed= max(max_observed, max(observed_qs))
    #plot
        plt.plot(expected_qs,observed_qs, 'o', markersize=2,label=labels[i])
    
    
    
    #Create line
    max_val = max(max_expected, max_observed)
    plt.plot([0, max_val],[0, max_val], 'r--')
    
    #label graph
    plt.xlabel('Expected -log10(p-values)')
    plt.ylabel('Observed -log10(p-values)')
    plt.title('QQ Plot for All Tissues')
    plt.legend()
    plt.xlim([0,5])
    plt.savefig('QQplot.png')
    plt.show()
    
dfs= [WB,CF,sun,nosun]
pvalue_cols= ['pvalue','pvalue','pvalue','pvalue']
labels=['Whole Blood','Fibroblasts','Sun Exposed Skin','Sun-free Skin']
qq_plot(dfs, pvalue_cols,labels)

# %%
#Upload fibroblast results
CF=pd.read_csv('/Users/halk/output/fibroblastresults.csv')

# %%
#create bar plot for lead genes from CF twas
def lead_genes_plot(CF, lead_n=10, gene_col='gene_name', p_value_col= 'pvalue'):
    lead_genes= CF.nsmallest(lead_n, p_value_col)
    lead_genes['-log10(pvalue)']= -np.log10(lead_genes[p_value_col])
    
    plt.figure(figsize=(12,10))
    sns.barplot(x='-log10(pvalue)', y=gene_col, data= lead_genes)
    plt.xlabel('-log10(p-value)')
    plt.ylabel('Gene')
    plt.title('Top 10 Significant Genes for Cultured Fibroblasts')
    plt.savefig('CFtop10.png')
    plt.show()
    
lead_genes_plot(CF)

# %%
#save sun exposed skin results as sun
sun=pd.read_csv('/Users/halk/output/skinsunexposed.csv')

# %%
#create bar plot for lead genes from Sun exposed skin twas
def lead_genes_plot(sun, lead_n=10, gene_col='gene_name', p_value_col= 'pvalue'):
    lead_genes= sun.nsmallest(lead_n, p_value_col)
    lead_genes['-log10(pvalue)']= -np.log10(lead_genes[p_value_col])
    
    plt.figure(figsize=(12,10))
    sns.barplot(x='-log10(pvalue)', y=gene_col, data= lead_genes)
    plt.xlabel('-log10(p-value)')
    plt.ylabel('Gene')
    plt.title('Top 10 Significant Genes for Sun Exposed Skin')
    plt.savefig('suntop10.png')
    plt.show()
    
lead_genes_plot(sun)

# %%
#save non-sun exposed skin results as nosun
nosun=pd.read_csv('/Users/halk/output/Skinnosunresults.csv')

# %%
#create bar plot for lead genes from Sun exposed skin twas
def lead_genes_plot(nosun, lead_n=10, gene_col='gene_name', p_value_col= 'pvalue'):
    lead_genes= nosun.nsmallest(lead_n, p_value_col)
    lead_genes['-log10(pvalue)']= -np.log10(lead_genes[p_value_col])
    
    plt.figure(figsize=(12,10))
    sns.barplot(x='-log10(pvalue)', y=gene_col, data= lead_genes)
    plt.xlabel('-log10(p-value)')
    plt.ylabel('Gene')
    plt.title('Top 10 Significant Genes for Sun-free Skin')
    plt.savefig('2nosuntop10.png')
    plt.show()
    
lead_genes_plot(nosun)

# %%
#create bar plot of top 10 zscores for sun exposed skin
data_sorted=sun.sort_values('zscore',ascending= False)
top_n=10
top_data= data_sorted.head(top_n)

#plot zscores
plt.figure(figsize=(12,10))
plt.barh(top_data['gene_name'],top_data['zscore'])
plt.xlabel('Z-score')
plt.ylabel('Gene')
plt.title('Top 10 Significant Z-scores for Sun Exposed Skin')
plt.savefig('zsuntop10.png')
plt.show()

# %%
#create bar plot of top 10 zscores for nonsun exposed skin
data_sorted=nosun.sort_values('zscore',ascending= False)
top_n=10
top_data= data_sorted.head(top_n)

#plot zscores
plt.figure(figsize=(12,10))
plt.barh(top_data['gene_name'],top_data['zscore'])
plt.xlabel('Z-score')
plt.ylabel('Gene')
plt.title('Top 10 Significant Z-scores for Sun-Free Skin')
plt.savefig('znosuntop10.png')
plt.show()

# %%
#create bar plot of top 10 zscores for cultured fibroblasts
data_sorted=CF.sort_values('zscore',ascending= False)
top_n=10
top_data= data_sorted.head(top_n)

#plot zscores
plt.figure(figsize=(12,10))
plt.barh(top_data['gene_name'],top_data['zscore'])
plt.xlabel('Z-score')
plt.ylabel('Gene')
plt.title('Top 10 Significant Z-scores for Cultured Fibroblasts')
plt.savefig('zCFtop10.png')
plt.show()

# %%
#create bar plot of top 10 zscores for whole blood
data_sorted=WB.sort_values('zscore',ascending= False)
top_n=10
top_data= data_sorted.head(top_n)

#plot zscores
plt.figure(figsize=(12,10))
plt.barh(top_data['gene_name'],top_data['zscore'])
plt.xlabel('Z-score')
plt.ylabel('Gene')
plt.title('Top 10 Significant Z-scores for Whole Blood')
plt.savefig('zWBtop10.png')
plt.show()
